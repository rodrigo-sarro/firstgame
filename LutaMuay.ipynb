# %%
from random import randint
import time

# %%
# to start the player need to put your name.
jogador =input('Welcome to The game, put your nome to start\n')
# 
print('--#--'*10)
print(f'           Now you are a fighter {jogador}')
print('--#--'*10)      
time.sleep(2)
# the computer start the game
print('\n              Lets Start the fight!!\n')
time.sleep(3)
print('--#--'*10) 
print('                     3')
time.sleep(1)
print('                     2')
time.sleep(1)
print('                     1')
time.sleep(1)
print('                   FIGHT!')
time.sleep(1)
# Out:
# Welcome to The game, Put your nome to start
# rodrigo
# --#----#----#----#----#----#----#----#----#----#--
#            Now you are a fighter rodrigo
# --#----#----#----#----#----#----#----#----#----#--
#
#               Lets Start the fight!!
#
# --#----#----#----#----#----#----#----#----#----#--
#                      3
#                      2
#                      1
#                    FIGHT!

# %%
# this is the life that each player have at the beginin.
lifeplayer = 500
pclife = 500

# %%
golpes = ['jab', 'jab direto', 'cotovelo direito', 'cotovelo esquerdo', 'chute direito', 'chute esquerdo', 'defesa']
listatest = [0, 1, 2, 3, 4, 5, 6]

# %%
while lifeplayer > 0 or pclife > 0:
    pc_golpe = randint(0, 5)
    
    #print('Escolha seu golpee:\n[0]jab\n[1]jab direto\n[2]cotovelo direito\n[3]cotovelo esquerdo\n[4]chute direito\n[5]chute esquerdo\n[6]defenda')
    
    golpejogador = str()
    # if the player puts something that is not a number, he will take damage
    # or puts something that is not a golpe, he will take damage too.
    while isinstance(golpejogador, str):
        
        golpejogador = input('\nEscolha seu golpe:\n[0]jab\n[1]jab direto\n[2]cotovelo direito\n[3]cotovelo esquerdo\n[4]chute direito\n[5]chute esquerdo\n[6]defenda\n')
        try:
            golpejogador = int(golpejogador)
            print(golpejogador)
            if golpejogador not in listatest:
                print("\nThis is not a golp, you lost life")
                time.sleep(1.5)
                
        except:
            if type(golpejogador) == str: 
                print("\nThis is not a golp, you lost life")
               
            time.sleep(1.5)
        #player loses life if he miss the golpe
        finally:
            lifeplayer -= 10    
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
    #ifs para cada possivel escolha do computar 
    if pc_golpe == 0:
        if golpejogador == 0:
            print('Ataques iguais ! os dois defenderam, ninguem foi atingido!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(2)
            
            
        if golpejogador == 1:
            lifeplayer -= 5
            pclife -= 10
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            lifeplayer -= 10
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('AIIII essa doeu, tome cuidado lutador')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            pclife -= 20.
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Boa acertou em cheio, conseguiu tirar o golpee dele!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            pclife -= 20
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Boa acertou em cheio, conseguiu tirar o golpe dele!')
            time.sleep(1.5)
            
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 5:
            pclife -= 20
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Boa acertou em cheio, conseguiu tirar o golpe dele!')
            time.sleep(1.5)
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
        
        if golpejogador == 6:
            print(f'{jogador} defendeu! boa ')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            
            
            
            
    if pc_golpe == 1:
        if golpejogador == 0:
            print('defendeu muito bom!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 1:
            print('Ataques iguais ! os dois defenderam, ninguem foi atingido!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            lifeplayer -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            lifeplayer -= 10.
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            pclife -= 20
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Boa acertou em cheio, conseguiu tirar o golpe dele!')
            time.sleep(1.5)
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
        
        if golpejogador == 5:
            lifeplayer -= 10.
            pclife -= 10
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
        
        
        
        if golpejogador == 6:
            print(f'{jogador} defendeu! boa ')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
    if pc_golpe == 2:
        if golpejogador == 0:
            print('toma cuidado!!')
            lifeplayer -= 5
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n") 
            time.sleep(1.5)
            
            
            
        if golpejogador == 1:
            print('um revidou o outro, cuidado!!')
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            lifeplayer -= 10 
            pclife -= 5
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n") 
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            print('Ataques iguais ! os dois defenderam, ninguem foi atingido!') 
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            lifeplayer -= 10.
            pclife -= 10
            print(f"O computador deu um {golpes[pc_golpe]}")
            
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            time.sleep(1.5)
            print('um revidou o outro')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            pclife -= 10
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('ele defendeu um pouco seu atk mas msm assim acertou, BOAA!')
            time.sleep(1.5)
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 5:
            lifeplayer -= 10.
            pclife -= 10
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('OS DOIS TOMARAM DANO, INCRIVEL!')
            time.sleep(1.5)
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 6:
            print(f'{jogador} defendeu! boa ')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
    if pc_golpe == 3:
        if golpejogador == 0:
            print(f"O computador deu um {golpes[pc_golpe]}")
            print(f'AI {jogador} toma cuidado!')
            time.sleep(1.5)
            
            lifeplayer -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 1:
            print('um revidou o outro, cuidado!!')            
            pclife -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            lifeplayer -= 10.
            pclife -= 10   
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            print('Ataques iguais ! os dois defenderam, ninguem foi atingido!') 
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            pclife -= 20
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Boa acertou em cheio, conseguiu tirar o golpe dele!')
            time.sleep(1.5)
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 5:
            pclife -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 6:
            print(f'{jogador} defendeu! boa ')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
    if pc_golpe == 4:
        if golpejogador == 0:
            print('toma cuidado!!')
            lifeplayer -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 1:
            print('toma cuidado!!')
            lifeplayer -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            lifeplayer -= 10.
            pclife -= 10   
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            lifeplayer -= 10 
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            print('Ataques iguais ! os dois defenderam, ninguem foi atingido!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 5:
        
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            pclife -= 5
            lifeplayer -= 5
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 6:
            print(f'{jogador} defendeu! boa ')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
    if pc_golpe == 5:
        if golpejogador == 0:
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('ai levou em cheio!')
            time.sleep(1.5)
            print('toma cuidado!!')
            lifeplayer -= 20
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 1:
            print('toma cuidado!!')
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            lifeplayer -= 10.
            pclife -= 10
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n") 
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            lifeplayer -= 10.
            pclife -= 10   
            print(f"O computador deu um {golpes[pc_golpe]}")
            print('Acertou bem o alvo, mas sofreu danos tambem, vamos la nao desista!')
            
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            lifeplayer -= 10 
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            pclife -= 5
            lifeplayer -= 5
            print('um revidou o outro, cuidado!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 5:
           
            print('Ataques iguais ! os dois defenderam, ninguem foi atingido!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 6:
            print(f'{jogador} defendeu! boa ')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
    if pc_golpe == 6:
        if golpejogador == 0:
            print('defesa do adversario!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 1:
            print('defesa do adversario!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 2:
            print('defesa do adversario!!')  
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 3:
            print('defesa do adversario!!') 
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 4:
            print('defesa do adversario!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 5:
            print('defesa do adversario!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
            
        if golpejogador == 6:
            print('defesa do adversario!!')
            print( f"\n{pclife} :: VIDAS : : {lifeplayer}\n")
            time.sleep(1.5)
            
            
# if the player lost all life he loses, 
# otherwise if the computer loses all life the player win
if pclife <= 0:
    
    print("UOUUUU YOU WINN!!\n")
    
if lifeplayer <= 0:
    
    print("NOT THIS TIME! TRY AGAIN!")
# Out:
# Escolha seu golpee:
# [0]jab
# [1]jab direto
# [2]cotovelo direito
# [3]cotovelo esquerdo
# [4]chute direito
# [5]chute esquerdo
# [6]defenda
# dfa
#
# This is not a golpee, u lost life
#
# 500 :: VIDAS : : 470

# %% [markdown]
# ####
